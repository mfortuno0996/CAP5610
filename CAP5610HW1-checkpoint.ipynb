# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

train_df = pd.read_csv('CAP5610HW1/train.csv')
print(train_df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(train_df.columns) #Gives the column heading
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_df.dtypes #Answers Q6 by breaking down features into data types
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train_df.describe() #Answers Q7 by generating a descriptive statistics table
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_df.nunique() #gets the number of unique variables for each feature
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
train_df[["Embarked","Cabin"]].count() #gives count of non NA values in Embarked and Cabin to determine total count
# Out:
# Embarked    889
# Cabin       204
# dtype: int64

# %%
freq_sex = train_df["Sex"].value_counts() #value_counts gives the frequency of unique variables, with the most frequent shown first
freq_emb = train_df["Embarked"].value_counts()
freq_cab = train_df["Cabin"].value_counts()
freq_pcl = train_df["Pclass"].value_counts()
freq_sur = train_df["Survived"].value_counts()
freq_tic = train_df["Ticket"].value_counts()
print(freq_sex, freq_emb, freq_cab, freq_pcl, freq_sur, freq_tic)
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64 S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64 G6             4
# B96 B98        4
# C23 C25 C27    4
# F2             3
# C22 C26        3
#               ..
# C90            1
# A5             1
# A16            1
# A10            1
# B19            1
# Name: Cabin, Length: 147, dtype: int64 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64 0    549
# 1    342
# Name: Survived, dtype: int64 CA. 2343         7
# 1601             7
# 347082           7
# 347088           6
# CA 2144          6
#                 ..
# 350046           1
# SC/PARIS 2133    1
# 28551            1
# 383121           1
# 2647             1
# Name: Ticket, Length: 681, dtype: int64

# %%
train_df[["Pclass","Survived"]].value_counts() #Answers Q9 by giving unique count of pclass for survived
# Out:
# Pclass  Survived
# 3       0           372
# 1       1           136
# 3       1           119
# 2       0            97
#         1            87
# 1       0            80
# dtype: int64

# %%
train_df[["Sex", "Survived"]].value_counts() #Answers Q10 by giving unique count of male and female for survived
# Out:
# Sex     Survived
# male    0           468
# female  1           233
# male    1           109
# female  0            81
# dtype: int64

# %%
train_df.hist(column="Age", by="Survived", bins=range(0,85,5)) #Answers Q11
plt.show()

# %%
train_df.hist(column="Age", by=["Pclass","Survived"], bins=range(0,85,5), figsize=(8,8)) #Answers Q12
plt.tight_layout()
plt.show()

# %%
train_df_Q13_0SM = train_df.loc[(train_df["Survived"] == 0) & (train_df["Embarked"] == "S") & (train_df["Sex"]=='male')]
F0SM = train_df_Q13_0SM["Fare"].mean()
train_df_Q13_0SF = train_df.loc[(train_df["Survived"] == 0) & (train_df["Embarked"] == "S") & (train_df["Sex"]=='female')]
F0SF = train_df_Q13_0SF["Fare"].mean()
train_df_Q13_1SM = train_df.loc[(train_df["Survived"] == 1) & (train_df["Embarked"] == "S") & (train_df["Sex"]=='male')]
F1SM = train_df_Q13_1SM["Fare"].mean()
train_df_Q13_1SF = train_df.loc[(train_df["Survived"] == 1) & (train_df["Embarked"] == "S") & (train_df["Sex"]=='female')]
F1SF = train_df_Q13_1SF["Fare"].mean()
train_df_Q13_0CM = train_df.loc[(train_df["Survived"] == 0) & (train_df["Embarked"] == "C") & (train_df["Sex"]=='male')]
F0CM = train_df_Q13_0CM["Fare"].mean()
train_df_Q13_0CF = train_df.loc[(train_df["Survived"] == 0) & (train_df["Embarked"] == "C") & (train_df["Sex"]=='female')]
F0CF = train_df_Q13_0CF["Fare"].mean()
train_df_Q13_1CM = train_df.loc[(train_df["Survived"] == 1) & (train_df["Embarked"] == "C") & (train_df["Sex"]=='male')]
F1CM = train_df_Q13_1CM["Fare"].mean()
train_df_Q13_1CF = train_df.loc[(train_df["Survived"] == 1) & (train_df["Embarked"] == "C") & (train_df["Sex"]=='female')]
F1CF = train_df_Q13_1CF["Fare"].mean()
train_df_Q13_0QM = train_df.loc[(train_df["Survived"] == 0) & (train_df["Embarked"] == "Q") & (train_df["Sex"]=='male')]
F0QM = train_df_Q13_0QM["Fare"].mean()
train_df_Q13_0QF = train_df.loc[(train_df["Survived"] == 0) & (train_df["Embarked"] == "Q") & (train_df["Sex"]=='female')]
F0QF = train_df_Q13_0QF["Fare"].mean()
train_df_Q13_1QM = train_df.loc[(train_df["Survived"] == 1) & (train_df["Embarked"] == "Q") & (train_df["Sex"]=='male')]
F1QM = train_df_Q13_1QM["Fare"].mean()
train_df_Q13_1QF = train_df.loc[(train_df["Survived"] == 1) & (train_df["Embarked"] == "Q") & (train_df["Sex"]=='female')]
F1QF = train_df_Q13_1QF["Fare"].mean()

F0S = {'Survived': [0,0], 'Sex': ['male','female'], 'Embarked': ['S','S'], 'Fare':[F0SM,F0SF]}
df_F0S = pd.DataFrame(data=F0S) 
F1S = {'Survived': [1,1], 'Sex': ['male','female'], 'Embarked': ['S','S'], 'Fare':[F1SM,F1SF]}
df_F1S = pd.DataFrame(data=F1S) 
F0C = {'Survived': [0,0], 'Sex': ['male','female'], 'Embarked': ['C','C'], 'Fare':[F0CM,F0CF]}
df_F0C = pd.DataFrame(data=F0C)
F1C = {'Survived': [1,1], 'Sex': ['male','female'], 'Embarked': ['C','C'], 'Fare':[F1CM,F1CF]}
df_F1C = pd.DataFrame(data=F1C)
F0Q = {'Survived': [0,0], 'Sex': ['male','female'], 'Embarked': ['Q','Q'], 'Fare':[F0QM,F0QF]}
df_F0Q = pd.DataFrame(data=F0Q)
F1Q = {'Survived': [1,1], 'Sex': ['male','female'], 'Embarked': ['Q','Q'], 'Fare':[F1QM,F1QF]}
df_F1Q = pd.DataFrame(data=F1Q)

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8)) #Answers Q13 by graphing the correlations between sex, survived, embarked, and fare average

df_F0S.plot(x='Sex', y='Fare', kind='bar', ax=axes[0,0], title='Survived=0|Embarked=S')
df_F1S.plot(x='Sex', y='Fare', kind='bar', ax=axes[0,1], title='Survived=1|Embarked=S')
df_F0C.plot(x='Sex', y='Fare', kind='bar', ax=axes[1,0], title='Survived=0|Embarked=C')
df_F1C.plot(x='Sex', y='Fare', kind='bar', ax=axes[1,1], title='Survived=1|Embarked=C')
df_F0Q.plot(x='Sex', y='Fare', kind='bar', ax=axes[2,0], title='Survived=0|Embarked=Q')
df_F1Q.plot(x='Sex', y='Fare', kind='bar', ax=axes[2,1], title='Survived=1|Embarked=Q')
plt.tight_layout()

# %%
tick_count = train_df["Ticket"].count() #Answers Q14 by finding the rate of duplicates
tick_dup = tick_count - train_df["Ticket"].nunique() 
tick_dup_rate = round(tick_dup/tick_count,2)
print(tick_dup_rate)
# Out:
# 0.24

# %%
test_df = pd.read_csv('CAP5610HW1/test.csv') #creates df from test.csv for Q15 and beyond
combine = [train_df, test_df] #combines both train_df and test_df

# %%
cab_null_train = train_df["Cabin"].isnull().sum() #answers Q15 by displaying the number of null values in Cabin feature
cab_null_test = test_df["Cabin"].isnull().sum()
cab_null_comb = cab_null_train + cab_null_test
print(cab_null_comb)

comb_count = train_df["Cabin"].count() + test_df["Cabin"].count()
cab_null_ratio = cab_null_comb/(cab_null_comb + comb_count)
print(cab_null_ratio)
# Out:
# 1014
# 0.774637127578304

# %%
train_df.rename(columns = {'Sex' : 'Gender'}, inplace=True) #answers Q16 by replacing Sex with Gender
train_df.replace({'male':0, 'female':1}, inplace=True) #replaces all instances of male and female with 0 and 1 respectively
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris       0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1  38.0      1
# 2                               Heikkinen, Miss. Laina       1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  35.0      1
# 4                             Allen, Mr. William Henry       0  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
emb_complete = train_df["Embarked"].fillna("S", inplace = True) #Answers Q18 by filling all NA values with the most common value "S"
emb_check= train_df["Embarked"].isnull().sum() #verifies values are filled
print(emb_complete)
print(emb_check)
# Out:
# None
# 0

# %%
test_df["Fare"].mode() #gets the mode of the Fare feature in test df
test_fare_complete = test_df["Fare"].fillna(7.75, inplace = True) #Answers Q19 by filling in missing value with mode generated
test_fare_check = test_df["Fare"].isnull().sum() #verifies value is filled
print(test_fare_check)

test_df["Fare"].astype('int64').dtype #convert Fare from float64 to int64 data type
# Out:
# 0
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
for ind,row in train_df.itterows():
    print(ind,row)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-126-03c717dd75d3> in <module>
# ----> 1 for ind,row in train_df.itterows():
#       2     print(ind,row)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'itterows'
